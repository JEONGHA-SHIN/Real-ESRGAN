# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/Dev/aicomp2023-2/Real-ESRGAN')
os.getcwd()
# Out:
# '/content/drive/MyDrive/Dev/aicomp2023-2/Real-ESRGAN'

# %%
# Install basicsr - https://github.com/xinntao/BasicSR
# We use BasicSR for both training and inference
# !pip install basicsr
# facexlib and gfpgan are for face enhancement
# !pip install facexlib
# !pip install gfpgan
# !pip install -r requirements.txt
# !python setup.py develop

# %%
# !python scripts/generate_meta_info_pairdata.py --input /content/drive/MyDrive/Dev/aicomp2023-2/Data/train/hr /content/drive/MyDrive/Dev/aicomp2023-2/Data/train/lr --meta_info datasets/train/meta_info/meta_info_dacon_pair.txt

# %%
# !python realesrgan/train.py -opt options/JH_finetune_realesrgan_x4plus_pairdata.yml --auto_resume
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Disable distributed.
# Path already exists. Rename it to /content/drive/MyDrive/Dev/aicomp2023-2/Real-ESRGAN/experiments/JH_finetune_RealESRGANx4plus_dacon_pairdata_archived_20231024_140049
# Path already exists. Rename it to /content/drive/MyDrive/Dev/aicomp2023-2/Real-ESRGAN/tb_logger/JH_finetune_RealESRGANx4plus_dacon_pairdata_archived_20231024_140049
# 2023-10-24 14:00:49,177 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
# ...

# %%
# !nvidia-smi
# Out:
# Tue Oct 24 14:00:44 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    23W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
